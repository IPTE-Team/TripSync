# %%
from pathlib import Path

import gtfstk as gt
import pandas as pd
import numpy as np

# %%
DATA_DIR = Path("data/")
# %ls {DATA_DIR}
# Out:
# gtfs.zip

# %%
# Read GTFS feed
feed = gt.read_gtfs(DATA_DIR/"gtfs.zip", dist_units="km")
feed.describe()
# Out:
#                            indicator                                value
# 0                           agencies  [LADOT, LADOT, LADOT, LADOT, LADOT]
# 1                           timezone                  America/Los_Angeles
# 2                         start_date                             20200418
# 3                           end_date                             20991231
# 4                         num_routes                                   62
# 5                          num_trips                                 6851
# 6                          num_stops                                 2678
# 7                         num_shapes                                  106
# 8                        sample_date                             20200423
# 9   num_routes_active_on_sample_date                                    0
# 10   num_trips_active_on_sample_date                                    0
# 11   num_stops_active_on_sample_date                                    0

# %%
feed.validate()
# Out:
#       type                                            message       table  \
# 0    error  Invalid agency_lang; maybe has extra space cha...      agency
# 4    error  Invalid feed_lang; maybe has extra space chara...   feed_info
# 1  warning                   Unrecognized column default_lang   feed_info
# 2  warning             Unrecognized column feed_contact_email   feed_info
# 3  warning               Unrecognized column feed_contact_url   feed_info
# 5  warning  Repeated pair (route_short_name, route_long_name)      routes
# 9  warning            Repeated pair (trip_id, departure_time)  stop_times
# 6  warning                       Unrecognized column level_id       stops
# 7  warning                  Unrecognized column platform_code       stops
# 8  warning                             Stop has no stop times       stops
#
#                                                 rows
# 0                                    [0, 1, 2, 3, 4]
# 4                                                [0]
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 5                                               [11]
# 9  [104, 114, 149, 159, 212, 214, 217, 236, 244, ...
# 6                                                 []
# 7                                                 []
# 8  [9, 17, 1384, 1856, 2009, 2249, 2267, 2268, 22...

# %%
# Trips table
feed.trips.T
# Out:
#                                   0                         1     \
# trip_id                 183-_3uV2MjGIO           183-_694En4HMYp
# route_id                          4445                      4446
# service_id                          14                        14
# trip_headsign          EXPO PARK - USC  Union Station/South Park
# trip_short_name                    NaN                       NaN
# direction_id                         0                         1
# block_id                        286991                    286993
# shape_id                         13220                     18480
# wheelchair_accessible              NaN                       NaN
#
#                                   2                         3     \
# trip_id                 183-_YUYwDUy6X           183--784XcojfNQ
# route_id                          4445                      4446
# service_id                          14                        14
# trip_headsign          EXPO PARK - USC  Union Station/South Park
# trip_short_name                    NaN                       NaN
# direction_id                         0                         0
# block_id                        286990                    286995
# shape_id                         13220                     17538
# wheelchair_accessible              NaN                       NaN
#
#                                            4                         5     \
# trip_id                         183--HZ6PxH8z9R           183--N47c2f9CGf
# route_id                                   4446                      4446
# service_id                                   14                        14
# trip_headsign          Union Station/South Park  Union Station/South Park
# trip_short_name                             NaN                       NaN
# direction_id                                  1                         0
# block_id                                 286979                    286997
# shape_id                                  18480                     17538
# wheelchair_accessible                       NaN                       NaN
#
#                                            6                       7     \
# trip_id                           183-00t9z1nfl           183-031a0ikvr
# route_id                                   4446                    4447
# service_id                                   12                      12
# trip_headsign          Union Station/South Park  Little Tokyo/City West
# trip_short_name                             NaN                     NaN
# direction_id                                  1                       0
# block_id                                 286914                  286895
# shape_id                                  18480                   18751
# wheelchair_accessible                       NaN                     NaN
#
#                                       8                    9     ...  \
# trip_id                      183-045yfk8ua        183-04hytkcoa  ...
# route_id                              4444                 4444  ...
# service_id                              12                   12  ...
# trip_headsign          To Fashion District  To Fashion District  ...
# trip_short_name                        NaN                  NaN  ...
# direction_id                             0                    0  ...
# block_id                            286926               286934  ...
# shape_id                             16607                16607  ...
# wheelchair_accessible                  NaN                  NaN  ...
#
#                                        6841                           6842  \
# trip_id                        47-zq19fh7pv                 47-zQBxObi71XT
# route_id                                 30                            801
# service_id                               10                             10
# trip_headsign          422 to Thousand Oaks  Sepulveda Park via Kester Ave
# trip_short_name                         NaN                            NaN
# direction_id                              0                              0
# block_id                             276891                         276838
# shape_id                              13226                           7854
# wheelchair_accessible                   NaN                            NaN
#
#                                                 6843          6844  \
# trip_id                               47-zQfMBOCKbgf  47-zr37opyrh
# route_id                                         801           867
# service_id                                        10            10
# trip_headsign          Sepulveda Park via Kester Ave  To Expo Park
# trip_short_name                                  NaN           NaN
# direction_id                                       0             1
# block_id                                      276837        276882
# shape_id                                        7854          4186
# wheelchair_accessible                            NaN           NaN
#
#                                                    6845  \
# trip_id                                   47-zRD6nUAqeG
# route_id                                            804
# service_id                                           11
# trip_headsign          Sepulveda Park via Van Nuys Blvd
# trip_short_name                                     NaN
# direction_id                                          0
# block_id                                         276976
# shape_id                                           7855
# wheelchair_accessible                               NaN
#
#                                                    6846  \
# trip_id                                  47-zrxsnpruzxW
# route_id                                            804
# service_id                                           10
# trip_headsign          Sepulveda Park via Van Nuys Blvd
# trip_short_name                                     NaN
# direction_id                                          0
# block_id                                         276843
# shape_id                                           7855
# wheelchair_accessible                               NaN
#
#                                                 6847  \
# trip_id                               47-zt_Hf3luUEO
# route_id                                         801
# service_id                                         9
# trip_headsign          Sepulveda Park via Kester Ave
# trip_short_name                                  NaN
# direction_id                                       0
# block_id                                      276826
# shape_id                                        7854
# wheelchair_accessible                            NaN
#
#                                             6848                6849  \
# trip_id                           47-zukU0RTiA0c      47-zWoSzHKcr5c
# route_id                                     800                5285
# service_id                                    11                  10
# trip_headsign          Civic Center via Whitsett  To Mission College
# trip_short_name                              NaN                 NaN
# direction_id                                   0                   0
# block_id                                  276972              276845
# shape_id                                   15089               18148
# wheelchair_accessible                        NaN                 NaN
#
#                                              6850
# trip_id                            47-ZZEi1FcnqL4
# route_id                                      799
# service_id                                      9
# trip_headsign          Civic Center via Hazeltine
# trip_short_name                               NaN
# direction_id                                    0
# block_id                                   276821
# shape_id                                    15088
# wheelchair_accessible                         NaN
#
# [9 rows x 6851 columns]

# %%
# Onl show route, trip, and shape columns: slice columns, AKA filter
feed.trips.filter(["route_id", "trip_id", "shape_id"]).T
# Out:
#                     0                1               2                3     \
# route_id            4445             4446            4445             4446
# trip_id   183-_3uV2MjGIO  183-_694En4HMYp  183-_YUYwDUy6X  183--784XcojfNQ
# shape_id           13220            18480           13220            17538
#
#                      4                5              6              7     \
# route_id             4446             4446           4446           4447
# trip_id   183--HZ6PxH8z9R  183--N47c2f9CGf  183-00t9z1nfl  183-031a0ikvr
# shape_id            18480            17538          18480          18751
#
#                    8              9     ...          6841            6842  \
# route_id           4444           4444  ...            30             801
# trip_id   183-045yfk8ua  183-04hytkcoa  ...  47-zq19fh7pv  47-zQBxObi71XT
# shape_id          16607          16607  ...         13226            7854
#
#                     6843          6844           6845            6846  \
# route_id             801           867            804             804
# trip_id   47-zQfMBOCKbgf  47-zr37opyrh  47-zRD6nUAqeG  47-zrxsnpruzxW
# shape_id            7854          4186           7855            7855
#
#                     6847            6848            6849            6850
# route_id             801             800            5285             799
# trip_id   47-zt_Hf3luUEO  47-zukU0RTiA0c  47-zWoSzHKcr5c  47-ZZEi1FcnqL4
# shape_id            7854           15089           18148           15088
#
# [3 rows x 6851 columns]

# %%
# 10 unique route_ids from trips.txt
# Remove slice to get all route_ids
np.vstack(feed.trips.route_id.unique())[0:10]
# Out:
# array([['4445'],
#        ['4446'],
#        ['4447'],
#        ['4444'],
#        ['4443'],
#        ['563'],
#        ['605'],
#        ['603'],
#        ['4868'],
#        ['572']], dtype='<U4')

# %%
# Find all trips of a specfic route: slice rows
feed.trips.loc[lambda x: x.route_id == "572"].T
# Out:
#                                                             1649  \
# trip_id                                         30-0__eb8iPEGugV
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287352
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1659  \
# trip_id                                         30-0_-1gLpMd2YmR
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287351
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1684  \
# trip_id                                         30-0_0cy0Vv1P4Tv
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287351
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1690  \
# trip_id                                         30-0_0s93ipl-1mp
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287352
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1722  \
# trip_id                                         30-0_1VodfOH7LmX
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287352
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1777  \
# trip_id                                         30-0_4AExetngIyJ
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287352
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1784  \
# trip_id                                         30-0_4lHazv_R7SB
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287352
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1841  \
# trip_id                                         30-0_6QjFQlMeMHT
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287351
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1891  \
# trip_id                                         30-0_9E--mlxDNbx
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287351
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1930  ...  \
# trip_id                                         30-0_ag28eca58XW  ...
# route_id                                                     572  ...
# service_id                                                     0  ...
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH  ...
# trip_short_name                                              NaN  ...
# direction_id                                                   0  ...
# block_id                                                  287351  ...
# shape_id                                                    8397  ...
# wheelchair_accessible                                        NaN  ...
#
#                                                             4307  \
# trip_id                                         30-2_OutoX_80hCU
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287463
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4337  \
# trip_id                                         30-2_px0_PM3Gckm
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287463
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4355  \
# trip_id                                         30-2_QU-hge-RF_o
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287463
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4356  \
# trip_id                                         30-2_QuNHb2k34Kq
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287463
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4385  \
# trip_id                                         30-2_rQ8mgbpag3k
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287462
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4442  \
# trip_id                                         30-2_tWMaszH7kAp
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287462
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4479  \
# trip_id                                         30-2_VDatc-H6AOY
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287462
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4542  \
# trip_id                                         30-2_XDFMJD8u4ty
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287463
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4598  \
# trip_id                                         30-2_zBk7y4apbkH
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287462
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4604
# trip_id                                         30-2_znMFe9a6ZSB
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287463
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
# [9 rows x 96 columns]

# %%
# Group all trips by route: group
feed.trips.groupby("route_id").get_group("572").T
# Out:
#                                                             1649  \
# trip_id                                         30-0__eb8iPEGugV
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287352
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1659  \
# trip_id                                         30-0_-1gLpMd2YmR
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287351
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1684  \
# trip_id                                         30-0_0cy0Vv1P4Tv
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287351
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1690  \
# trip_id                                         30-0_0s93ipl-1mp
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287352
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1722  \
# trip_id                                         30-0_1VodfOH7LmX
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287352
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1777  \
# trip_id                                         30-0_4AExetngIyJ
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287352
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1784  \
# trip_id                                         30-0_4lHazv_R7SB
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287352
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1841  \
# trip_id                                         30-0_6QjFQlMeMHT
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287351
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1891  \
# trip_id                                         30-0_9E--mlxDNbx
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287351
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1930  ...  \
# trip_id                                         30-0_ag28eca58XW  ...
# route_id                                                     572  ...
# service_id                                                     0  ...
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH  ...
# trip_short_name                                              NaN  ...
# direction_id                                                   0  ...
# block_id                                                  287351  ...
# shape_id                                                    8397  ...
# wheelchair_accessible                                        NaN  ...
#
#                                                             4307  \
# trip_id                                         30-2_OutoX_80hCU
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287463
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4337  \
# trip_id                                         30-2_px0_PM3Gckm
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287463
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4355  \
# trip_id                                         30-2_QU-hge-RF_o
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287463
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4356  \
# trip_id                                         30-2_QuNHb2k34Kq
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287463
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4385  \
# trip_id                                         30-2_rQ8mgbpag3k
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287462
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4442  \
# trip_id                                         30-2_tWMaszH7kAp
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287462
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4479  \
# trip_id                                         30-2_VDatc-H6AOY
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287462
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4542  \
# trip_id                                         30-2_XDFMJD8u4ty
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287463
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4598  \
# trip_id                                         30-2_zBk7y4apbkH
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287462
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4604
# trip_id                                         30-2_znMFe9a6ZSB
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287463
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
# [9 rows x 96 columns]

# %%
# Computer number of trips per route: split, apply, combine
def my_agg(group):
    d = {}
    d["num_trips"] = group.shape[0]
    return pd.Series(d)

# Use method chaining
(
    feed.trips
    # Split
    .groupby("route_id")
    .apply(my_agg)
    .reset_index()
    # Join in route short name from feed.routes
    .merge(feed.routes.filter(["route_id", "route_short_name", "route_long_name", "route_type"]))
    .sort_values("num_trips", ascending=False)
    .T
)
# Out:
#                       15                         22      17  \
# route_id            4444                       4869    4446
# num_trips            576                        448     442
# route_short_name       E       Pico Union/Echo Park       D
# route_long_name   DASH E  DASH Pico Union/Echo Park  DASH D
# route_type             3                          3       3
#
#                                           19                           21  \
# route_id                                4577                         4868
# num_trips                                311                          280
# route_short_name       Observatory/Los Feliz       El Sereno/City Terrace
# route_long_name   DASH Observatory/Los Feliz  DASH El Sereno/City Terrace
# route_type                                 3                            3
#
#                       18      14      16                        44     59  \
# route_id            4447    4443    4445                       712    870
# num_trips            225     209     193                       193    192
# route_short_name       A       B       F       Chesterfield Square    142
# route_long_name   DASH A  DASH B  DASH F  DASH Chesterfield Square  CE142
# route_type             3       3       3                         3      3
#
#                   ...     6       55       0       58      13      60     5   \
# route_id          ...     27     858     1458     869    4291     871     26
# num_trips         ...     14      12       11      10       8       8      6
# route_short_name  ...    438    437A     438B     574     439     534    431
# route_long_name   ...  CE438  CE437A  CE438B   CE574   CE439   CE534   CE431
# route_type        ...      3       3        3       3       3       3      3
#
#                      11      12      1
# route_id           4278    4290    1524
# num_trips             4       4       2
# route_short_name    438    437B    431B
# route_long_name   CE438  CE437B  CE431B
# route_type            3       3       3
#
# [5 rows x 62 columns]

# %%
# Fill in shape_dist_traveled column of stop_times for later distance calculations.
trip_stats = feed.compute_trip_stats()
feed = feed.append_dist_to_stop_times(trip_stats)
feed.stop_times.T
# Out:
#                               97               98               99      \
# trip_id              183--784XcojfNQ  183--784XcojfNQ  183--784XcojfNQ
# arrival_time                15:15:00         15:17:00         15:19:00
# departure_time              15:15:00         15:17:00         15:19:00
# stop_id                      6715955          6715956          6715957
# stop_sequence                      0                1                2
# stop_headsign                    NaN              NaN              NaN
# pickup_type                        0                0                0
# drop_off_type                    NaN              NaN              NaN
# shape_dist_traveled                0         0.230718         0.531221
# timepoint                          1                0                0
#
#                               100              101              102     \
# trip_id              183--784XcojfNQ  183--784XcojfNQ  183--784XcojfNQ
# arrival_time                15:20:00         15:22:00         15:23:00
# departure_time              15:20:00         15:22:00         15:23:00
# stop_id                      6715958          6715959          6715960
# stop_sequence                      3                4                5
# stop_headsign                    NaN              NaN              NaN
# pickup_type                        0                0                0
# drop_off_type                    NaN              NaN              NaN
# shape_dist_traveled         0.720078         0.925299          1.07141
# timepoint                          0                0                1
#
#                               103              104              105     \
# trip_id              183--784XcojfNQ  183--784XcojfNQ  183--784XcojfNQ
# arrival_time                15:26:00         15:26:00         15:27:00
# departure_time              15:26:00         15:26:00         15:27:00
# stop_id                      6715962          6715963          6715992
# stop_sequence                      6                7                8
# stop_headsign                    NaN              NaN              NaN
# pickup_type                        0                0                0
# drop_off_type                    NaN              NaN              NaN
# shape_dist_traveled          1.74717          1.96805          2.16942
# timepoint                          0                0                1
#
#                               106     ...          229356          229357  \
# trip_id              183--784XcojfNQ  ...  47-zukU0RTiA0c  47-zukU0RTiA0c
# arrival_time                15:28:00  ...        16:12:00        16:13:00
# departure_time              15:28:00  ...        16:12:00        16:13:00
# stop_id                      6715993  ...          391853          391854
# stop_sequence                      9  ...              34              35
# stop_headsign                    NaN  ...             NaN             NaN
# pickup_type                        0  ...               0               0
# drop_off_type                    NaN  ...             NaN             NaN
# shape_dist_traveled          2.37346  ...         14979.8         15336.5
# timepoint                          0  ...               0               0
#
#                              229358          229359          229360  \
# trip_id              47-zukU0RTiA0c  47-zukU0RTiA0c  47-zukU0RTiA0c
# arrival_time               16:14:00        16:16:00        16:17:00
# departure_time             16:14:00        16:16:00        16:17:00
# stop_id                      391855          391856          391857
# stop_sequence                    36              37              38
# stop_headsign                   NaN             NaN             NaN
# pickup_type                       0               0               0
# drop_off_type                   NaN             NaN             NaN
# shape_dist_traveled         15693.1         16406.5         16763.1
# timepoint                         0               1               0
#
#                              229361          229362          229363  \
# trip_id              47-zukU0RTiA0c  47-zukU0RTiA0c  47-zukU0RTiA0c
# arrival_time               16:18:00        16:19:00        16:20:00
# departure_time             16:18:00        16:19:00        16:20:00
# stop_id                      391858          391859          391860
# stop_sequence                    39              40              41
# stop_headsign                   NaN             NaN             NaN
# pickup_type                       0               0               0
# drop_off_type                   NaN             NaN             NaN
# shape_dist_traveled         17119.8         17476.5         17833.1
# timepoint                         0               0               0
#
#                              229364          229365
# trip_id              47-zukU0RTiA0c  47-zukU0RTiA0c
# arrival_time               16:21:00        16:23:00
# departure_time             16:21:00        16:23:00
# stop_id                      391861         4017085
# stop_sequence                    42              43
# stop_headsign                   NaN             NaN
# pickup_type                       0               0
# drop_off_type                   NaN             NaN
# shape_dist_traveled         18189.8         18903.1
# timepoint                         0               1
#
# [10 rows x 229434 columns]

# %% [markdown]
# stop_times.txt has an optional field that describes the distance that the trip traverses at each stop.

# %%
# Trip stats
trip_stats.T
# Out:
#                           4667            4623          4668            4734  \
# trip_id           45-0_2086796  45-0_0g0ggqtdd  45-0_2086798  45-0_53w9llpvz
# route_id                  1458            1458          1458            1458
# route_short_name          438B            438B          438B            438B
# route_type                   3               3             3               3
# direction_id                 0               0             0               0
# shape_id                 11697           11697         11697           11697
# num_stops                   19              19            19              19
# start_time            16:10:00        16:30:00      16:40:00        16:50:00
# end_time              17:09:00        17:29:00      17:39:00        17:49:00
# start_stop_id          4744526         4744526       4744526         4744526
# end_stop_id            1224017         1224017       1224017         1224017
# is_loop                      0               0             0               0
# duration              0.983333        0.983333      0.983333        0.983333
# distance               33049.6         33049.6       33049.6         33049.6
# speed                  33609.8         33609.8       33609.8         33609.8
#
#                           4669            5291          4665            5322  \
# trip_id           45-0_2086800  45-0_y2q4j7qu6  45-0_2086791  45-0_zlcso1suc
# route_id                  1458            1458          1458            1458
# route_short_name          438B            438B          438B            438B
# route_type                   3               3             3               3
# direction_id                 0               1             1               1
# shape_id                 11697           13221         13221           13221
# num_stops                   19              20            20              20
# start_time            17:00:00        05:45:00      06:00:00        06:30:00
# end_time              17:59:00        06:38:00      06:50:00        07:23:00
# start_stop_id          4744526         1224017       1224017         1224017
# end_stop_id            1224017         4744526       4744526         4744526
# is_loop                      0               0             0               0
# duration              0.983333        0.883333      0.833333        0.883333
# distance               33049.6         32816.3       32816.3         32816.3
# speed                  33609.8         37150.5       39379.6         37150.5
#
#                           4666            4742  ...  \
# trip_id           45-0_2086793  45-0_61hou6p51  ...
# route_id                  1458            1458  ...
# route_short_name          438B            438B  ...
# route_type                   3               3  ...
# direction_id                 1               1  ...
# shape_id                 13221           13221  ...
# num_stops                   20              20  ...
# start_time            06:50:00        07:10:00  ...
# end_time              07:41:00        08:03:00  ...
# start_stop_id          1224017         1224017  ...
# end_stop_id            4744526         4744526  ...
# is_loop                      0               0  ...
# duration                  0.85        0.883333  ...
# distance               32816.3         32816.3  ...
# speed                  38607.4         37150.5  ...
#
#                                                4642  \
# trip_id                              45-0_1gfsl1q1s
# route_id                                        900
# route_short_name  Union Station/Bunker Hill Shuttle
# route_type                                        3
# direction_id                                      1
# shape_id                                      11737
# num_stops                                         4
# start_time                                 16:50:00
# end_time                                   17:15:00
# start_stop_id                                446728
# end_stop_id                                  432147
# is_loop                                           0
# duration                                   0.416667
# distance                                    3665.57
# speed                                       8797.36
#
#                                                5072  \
# trip_id                              45-0_ixhoe1gpd
# route_id                                        900
# route_short_name  Union Station/Bunker Hill Shuttle
# route_type                                        3
# direction_id                                      1
# shape_id                                      11737
# num_stops                                         4
# start_time                                 16:55:00
# end_time                                   17:20:00
# start_stop_id                                446728
# end_stop_id                                  432147
# is_loop                                           0
# duration                                   0.416667
# distance                                    3665.57
# speed                                       8797.36
#
#                                                4617  \
# trip_id                              45-0_03r014nxj
# route_id                                        900
# route_short_name  Union Station/Bunker Hill Shuttle
# route_type                                        3
# direction_id                                      1
# shape_id                                      11737
# num_stops                                         4
# start_time                                 17:00:00
# end_time                                   17:25:00
# start_stop_id                                446728
# end_stop_id                                  432147
# is_loop                                           0
# duration                                   0.416667
# distance                                    3665.57
# speed                                       8797.36
#
#                                                5230  \
# trip_id                              45-0_titvhztys
# route_id                                        900
# route_short_name  Union Station/Bunker Hill Shuttle
# route_type                                        3
# direction_id                                      1
# shape_id                                      11737
# num_stops                                         4
# start_time                                 17:03:00
# end_time                                   17:26:00
# start_stop_id                                446728
# end_stop_id                                  432147
# is_loop                                           0
# duration                                   0.383333
# distance                                    3665.57
# speed                                       9562.35
#
#                                                4701  \
# trip_id                              45-0_2v7yr3z0l
# route_id                                        900
# route_short_name  Union Station/Bunker Hill Shuttle
# route_type                                        3
# direction_id                                      1
# shape_id                                      11737
# num_stops                                         4
# start_time                                 17:06:00
# end_time                                   17:29:00
# start_stop_id                                446728
# end_stop_id                                  432147
# is_loop                                           0
# duration                                   0.383333
# distance                                    3665.57
# speed                                       9562.35
#
#                                                4644  \
# trip_id                              45-0_1jn825esi
# route_id                                        900
# route_short_name  Union Station/Bunker Hill Shuttle
# route_type                                        3
# direction_id                                      1
# shape_id                                      11737
# num_stops                                         4
# start_time                                 17:09:00
# end_time                                   17:32:00
# start_stop_id                                446728
# end_stop_id                                  432147
# is_loop                                           0
# duration                                   0.383333
# distance                                    3665.57
# speed                                       9562.35
#
#                                                4704  \
# trip_id                              45-0_34g5wlxx8
# route_id                                        900
# route_short_name  Union Station/Bunker Hill Shuttle
# route_type                                        3
# direction_id                                      1
# shape_id                                      11737
# num_stops                                         4
# start_time                                 17:15:00
# end_time                                   17:35:00
# start_stop_id                                446728
# end_stop_id                                  432147
# is_loop                                           0
# duration                                   0.333333
# distance                                    3665.57
# speed                                       10996.7
#
#                                                4964  \
# trip_id                              45-0_c1a94ugbv
# route_id                                        900
# route_short_name  Union Station/Bunker Hill Shuttle
# route_type                                        3
# direction_id                                      1
# shape_id                                      11737
# num_stops                                         4
# start_time                                 17:19:00
# end_time                                   17:39:00
# start_stop_id                                446728
# end_stop_id                                  432147
# is_loop                                           0
# duration                                   0.333333
# distance                                    3665.57
# speed                                       10996.7
#
#                                                5325  \
# trip_id                              45-0_zns7c4ve2
# route_id                                        900
# route_short_name  Union Station/Bunker Hill Shuttle
# route_type                                        3
# direction_id                                      1
# shape_id                                      11737
# num_stops                                         4
# start_time                                 17:35:00
# end_time                                   17:55:00
# start_stop_id                                446728
# end_stop_id                                  432147
# is_loop                                           0
# duration                                   0.333333
# distance                                    3665.57
# speed                                       10996.7
#
#                                                5198
# trip_id                              45-0_rd2osu9or
# route_id                                        900
# route_short_name  Union Station/Bunker Hill Shuttle
# route_type                                        3
# direction_id                                      1
# shape_id                                      11737
# num_stops                                         4
# start_time                                 17:55:00
# end_time                                   18:15:00
# start_stop_id                                446728
# end_stop_id                                  432147
# is_loop                                           0
# duration                                   0.333333
# distance                                    3665.57
# speed                                       10996.7
#
# [15 rows x 6851 columns]

# %% [markdown]
# Fewer num_trip_starts than num_trip_end because some trips end the following day.

# %%
# Map our routes
feed.map_routes(route_ids=["4445", "4446"])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_e0f1566afc4d4e87965c0bd8b5697789%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e0f1566afc4d4e87965c0bd8b5697789%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e0f1566afc4d4e87965c0bd8b5697789%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_e0f1566afc4d4e87965c0bd8b5697789%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...
