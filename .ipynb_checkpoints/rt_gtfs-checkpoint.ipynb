# %% [markdown]
# # Realtime GTFS
#
# Requesting realtime gtfs data from LADOT (Los Angeles Department of Transportation).

# %% [markdown]
# ## Imports

# %%
import requests

# %% [markdown]
# ## Urls

# %%
# gtfs_schedule_url = "https://ladotbus.com/gtfs" # limited by rate
ladot_vehicle_positions_url = "https://ladotbus.com/gtfs-rt/vehiclepositions"
ladot_service_alerts_url = "https://ladotbus.com/gtfs-rt/alerts"
ladot_trip_updates_url = "https://ladotbus.com/gtfs-rt/tripupdates"

# %%
appID = "E0454BB2EA64AD6A937D30B6A"
trimet_veh_pos_url = f"http://developer.trimet.org/ws/V1/VehiclePositions?locIDs=6849,6850&appID={appID}"

# %%
f = requests.get(trimet_veh_pos_url)
print(f.text)
# Out:
# 1üİõ”S
# 105"L
#
# 11571515*100
# 6BqÇõÂ“C& (íİõ”:9833B
# 105Blue to HillsboroX
# 107"Q
#
# ;¾5B»"õÂ¯C (öİõ”:13132B
# 107Green Line to GatewayR
# 108"K
#
# !6B‡=õÂ�C (ñİõ”:8373B
# 108Blue to SW 185thS
# 109"L
#
# J6BMaõÂ€C (÷İõ”:9757B
# 109Blue to HillsboroZ
# 4207"R
#
# 'É5BFõÂ†C (òİõ”:2570B
# 420733 To Clackamas CollegeQ
# 4208"I
#
# $76B¥=õÂ€³CB (éİõ”:7526B
# 420875 to St JohnsS
# 113"L
#
# Ü6BEÖôÂ€�C (èİõ”:8359B
# 113Blue to HillsboroS
# 116"L
#
# 11571516*100÷5B„šõÂ[C (ôİõ”:9818B
# 116Blue to HillsboroQ
# 4213"I
#
# ö5B™:õÂ‡C% (ìİõ”:2733B
# 421317 To SaratogaQ
# 118"J
#
# )6BBõÂ´B" (ôİõ”:8348B
# 118Blue to GreshamS
# 119"L
#
# Ê6BÿğõÂ€‡C+ (èİõ”:9844B
# 119Blue to HillsboroQ
# 4216"I
#
# 8)6BFHõÂK (éİõ”:7197B
# 421617 To SaratogaQ
# 120"J
#
# v6BbğôÂğB) (úİõ”:8355B
# 120Blue to GreshamQ
# 124"J
#
# È6BÅôõÂ´B (ğİõ”:9843B
# 124Blue to GreshamO
# 4221"G
#
# V6BÊYõÂ_C (àİõ”:9301B
# 9  Gresham TCS
# 4226"K
#
# ªh6Bg†õÂhB (àİõ”:10697B
# 422675 to 45-HarneyQ
# 4227"I
#
# ½÷5BX(õÂ (øİõ”:7935B
# 422772 Swan IslandR
# 4231"J
#
# £&6BñiõÂ2C (ïİõ”:8484B
# 423177 To TroutdaleQ
# 4232"I
#
# (Ú5BT;õÂ (àİõ”:7546B
# 423275 to St JohnsS
# 201"L
#
# ç6BñøõÂ€…C, (ïİõ”:9845B
# 201Blue to HillsboroW
# 202"P
#
# �Y6B®/õÂC (èİõ”:10579B
# 202Red Line to Beaverton[
# 205"T
#
# wı5BäKõÂ6C (áİõ”:13714B
# 205Orange Line to MilwaukieS
# 207"L
#
# T!6BÃ&õÂ€“C (ëİõ”:8371B
# 207Blue to HillsboroV
# 208"O
#
# ’66BÔ!õÂC (ßİõ”:8370B
# 208Red Line to BeavertonX
# 209"Q
#
# ;¾5B»"õÂ¯C (öİõ”:13132B
# 209Green Line to GatewayS
# 211"L
#
# 11571516*100÷5B„šõÂ[C (ôİõ”:9818B
# 211Blue to HillsboroY
# 212"R
#
# <¾5B»"õÂ¯C (÷Úõ”:13132B
# 212Green Line to City CtrZ
# 213"S
#
# 	6B!^õÂ€ªC (öİõ”:10293B
# 213Green Line to ClackamasX
# 214"Q
#
# 4"6B0õÂiC (æİõ”:8372B
# 214Green Line to City CtrS
# 216"L
#
# J6BMaõÂ€C (÷İõ”:9757B
# 216Blue to HillsboroV
# 218"O
#
# ’66BÔ!õÂC (ßİõ”:8370B
# 218Red Line to BeavertonQ
# 219"J
#
# È6BÅôõÂ´B (ğİõ”:9843B
# 219Blue to GreshamQ
# 220"J
#
# v6BbğôÂğB) (úİõ”:8355B
# 220Blue to GreshamR
# 223"K
#
# !6B‡=õÂ�C (ñİõ”:8373B
# 223Blue to SW 185thS
# 224"L
#
# Ü6BEÖôÂ€�C (æİõ”:8359B
# 224Blue to HillsboroS
# 226"L
#
# ç6BñøõÂ€…C, (ïİõ”:9845B
# 226Blue to Hillsboro_
# 227"X
#
# 6B]õÂ€�C (áİõ”:10293B#
# 227Orange Line to City Ctr/Expo_
# 228"X
#
# ¹5B%EõÂ±C (ñİõ”:13720B#
# 228Orange Line to City Ctr/ExpoZ
# 229"S
#
# 	6B!^õÂ€ªC (öİõ”:10293B
# 229Green Line to ClackamasS
# 230"L
#
# 11571515*100
# 6BqÇõÂ“C& (íİõ”:9833B
# 230Blue to Hillsboro_
# 232"X
#
# ¹5B%EõÂ±C (ñİõ”:13720B#
# 232Orange Line to City Ctr/ExpoW
# 233"P
#
# �Y6B®/õÂC (èİõ”:10579B
# 233Red Line to BeavertonP
# 234"I
#
# ëI6B™õÂ€•C (ßİõ”:10574B
# 234Red to Airport_
# 235"X
#
# Õk6B_õÂKC (áİõ”:11498B#
# 235Yellow Line to City Ctr/MilwS
# 238"L
#
# Ü6BEÖôÂ€�C (æİõ”:8359B
# 238Blue to Hillsboro[
# 239"T
#
# wı5BäKõÂ6C (áİõ”:13714B
# 239Orange Line to MilwaukieV
# 243"O
#
# n6B(]õÂ€‘C (ñİõ”:8384B
# 243Red Line to BeavertonZ
# 245"S
#
# 6Bg\õÂHC (äİõ”:7618B
# 245Orange Line to MilwaukieX
# 248"Q
#
# 4"6B0õÂiC (æİõ”:8372B
# 248Green Line to City CtrQ
# 249"J
#
# )6BBõÂ´B" (ôİõ”:8348B
# 249Blue to GreshamY
# 251"R
#
# <¾5B»"õÂ¯C (÷Úõ”:13132B
# 251Green Line to City CtrR
# 302"K
#
# s6BÀ‹õÂ�C (ßİõ”:9624B
# 302Blue to SW 185th_
# 303"X
#
# Õk6B_õÂKC (áİõ”:11498B#
# 303Yellow Line to City Ctr/MilwR
# 304"K
#
# s6BÀ‹õÂ�C (ßİõ”:9624B
# 304Blue to SW 185th_
# 305"X
#
# 6B]õÂ€�C (áİõ”:10293B#
# 305Orange Line to City Ctr/ExpoZ
# 306"S
#
# mP6B7]õÂ (úİõ”:11515B
# 306Yellow Line to Expo CtrP
# 308"I
#
# ëI6B™õÂ€•C (ßİõ”:10574B
# 308Red to AirportS
# 310"L
#
# T!6BÃ&õÂ€“C (ëİõ”:8371B
# 310Blue to HillsboroS
# 313"L
#
# Ê6BÿğõÂ€‡C+ (èİõ”:9844B
# 313Blue to HillsboroO
# 316"H
#
# j6Bœ4õÂPB (íİõ”:8345B
# 316Red to AirportV
# 318"O
#
# n6B(]õÂ€‘C (ñİõ”:8384B
# 318Red Line to BeavertonZ
# 319"S
#
# 6Bg\õÂHC (äİõ”:7618B
# 319Orange Line to MilwaukieS
# 320"L
#
# Ü6BEÖôÂ€�C (èİõ”:8359B
# 320Blue to HillsboroZ
# 321"S
#
# Å6BÚXõÂ4C (÷İõ”:11508B
# 321Yellow Line to Expo CtrO
# 323"H
#
# j6Bœ4õÂPB (íİõ”:8345B
# 323Red to AirportZ
# 325"S
#
# mP6B7]õÂ (úİõ”:11515B
# 325Yellow Line to Expo CtrZ
# 327"S
#
# Å6BÚXõÂ4C (÷İõ”:11508B
# 327Yellow Line to Expo CtrP
# 401"I
#
# 6BdõÂàB (úİõ”:10118B
# 401Red to AirportS
# 402"L
#
# k6BËWõÂ5C (íİõ”:8378B
# 402Blue to HillsboroP
# 404"I
#
# 6BdõÂàB (úİõ”:10118B
# 404Red to Airport[
# 406"T
#
# e»5BkEõÂ C (ñİõ”:13720B
# 406Orange Line to MilwaukieZ
# 408"S
#
# 6B½ õÂ=C (âİõ”:13124B
# 408Green Line to ClackamasO
# 409"H
#
# o6BĞZõÂÜB (àİõ”:8336B
# 409Red to AirportZ
# 410"S
#
# 6B½ õÂ=C (âİõ”:13124B
# 410Green Line to ClackamasS
# 411"L
#
# ¬6B�úôÂ‡C	 (úİõ”:8366B
# 411Blue to Hillsboro_
# 412"X
#
# ¤i6BÈ^õÂşB (Ãİõ”:11499B#
# 412Yellow Line to City Ctr/Milw[
# 413"T
#
# e»5BkEõÂ C (ñİõ”:13720B
# 413Orange Line to MilwaukieS
# 415"L
#
# ¬6B�úôÂ‡C	 (úİõ”:8366B
# 415Blue to HillsboroO
# 421"H
#
# �÷5B2šõÂB (êİõ”:9821B
# 421Red to AirportX
# 422"Q
#
# µ6B"õÂ@ (÷İõ”:13138B
# 422Green Line to GatewayO
# 521"H
#
# o6BĞZõÂÜB (àİõ”:8336B
# 521Red to AirportR
# 522"K
#
# 6BÛ�õÂòB (êİõ”:10120B
# 522Blue to Gresham_
# 528"X
#
# é5BşGõÂ¯C (æİõ”:13724B#
# 528Orange Line to City Ctr/ExpoR
# 530"K
#
# 6BÛ�õÂòB (êİõ”:10120B
# 530Blue to GreshamO
# 532"H
#
# �÷5B2šõÂB (êİõ”:9821B
# 532Red to Airport_
# 533"X
#
# é5BşGõÂ¯C (æİõ”:13724B#
# 533Orange Line to City Ctr/ExpoX
# 534"Q
#
# µ6B"õÂ@ (÷İõ”:13138B
# 534Green Line to Gateway_
# 536"X
#
# ¤i6BÈ^õÂşB (Ãİõ”:11499B#
# 536Yellow Line to City Ctr/MilwS
# 538"L
#
# k6BËWõÂ5C (íİõ”:8378B
# 538Blue to HillsboroR
# 3005"J
#
# :ô5B|›õÂ�C (ìİõ”:8262B
# 300576 To Tigard TCU
# 3009"M
#
# ¸6B+öÂ‡C@ (ìİõ”:4307B
# 300957 To Forest GroveO
# 3012"G
#
# l	6BŒõÂÒB (ûİõ”:233B
# 20 Gresham TCU
# 3016"M
#
# Nü5B�ÈõÂ�C (õİõ”:5586B
# 301657 To Forest GroveQ
# 3017"I
#
# È–5B™õÂ7C (àİõ”:4260B
# 301794 To SherwoodW
# 3027"O
#
# 11558713*35
# ‰5B%GõÂ(CP (òİõ”:6333B
# 302735 To Oregon City TC[
# 3030"S
#
# #÷5B7šõÂUC (àİõ”:9985B
# 303088 To Willow Ck-185th TC[
# 3032"S
#
# Ï6Bz½õÂæB# (øİõ”:9610B
# 303252 To 185th & West Union`
# 3034"X
#
# ˆ£5Bi‡õÂ4C* (ìİõ”:13900B$
# 303476 To Meridian Park HospitalQ
# 3037"I
#
# ¡R6B.SõÂ€†C (ïİõ”:5950B
# 30378  OHSU-VA HospT
# 3041"L
#
# œ6BkúõÂ‡C* (ìİõ”:259B
# 304157 To Forest GroveU
# 3043"M
#
# ÷5Bû™õÂTC (ûİõ”:9654B
# 304357 To Forest GroveU
# 3045"M
#
# qñ5B1§õÂ�B, (øİõ”:1661B
# 304552 To Beaverton TCS
# 3046"K
#
# Q16Br)õÂ´B$ (øİõ”:1908B
# 304624 To Gateway TC'
# ˆ¾5B#õÂC(òİõ”B
# 3052Z
# 3058"R
#
# :6B]hõÂC (àİõ”:115B
# 305872 To Clackamas Town CtrV
# 3101"N
#
# ÌÀ5B”&õÂ‡CF (ìİõ”:12921B
# 310171 To Clackamas TCP
# 3108"H
#
# )_6B]õÂ!C (éİõ”:2648B
# 31086  To PortlandU
# 3115"M
#
# 6BÂ5õÂ†C (ûİõ”:3404B
# 311571 To Clackamas TCS
# 3116"K
#
# ªh6Bg†õÂhB (ãİõ”:10697B
# 311675 to 45-HarneyR
# 3122"J
#
# 1è5B;õÂ4CZ (ìİõ”:7564B
# 312275 to 45-HarneyY
# 3123"Q
#
# Kç5Bí(õÂ‡C (æİõ”:1551B
# 312319 Gateway TC via 28thP
# 3129"H
#
# ûü5B}õÂ€…C$ (æİõ”:4572B
# 31299  To PortlandR
# 3130"J
#
# {O6B÷kõÂèB (àİõ”:3479B
# 313075 to 45-Harney^
# 3132"V
#
# Ğp5B‡5õÂ€£C (æİõ”:8758B#
# 313233 To Clackamas Town CenterQ
# 3133"I
#
# ÿ6B—ÚôÂ²B (ïİõ”:12757B
# 31339  To PortlandS
# 3137"K
#
# 6B']õÂ AM (ãİõ”:7756B
# 31379  To NW FlandersO
# 3142"G
#
# U6BæõÂ°B9 (ïİõ”:1400B
# 2  Gresham TCQ
# 3154"I
#
# V$6B^UõÂ€³C	 (ïİõ”:6357B
# 31544  To St. JohnsP
# 3155"H
#
# ­.6B¿RõÂ4C (ãİõ”:5938B
# 31556  To PortlandU
# 3156"M
#
# (Ø5Bn�õÂ A5 (õİõ”:5170B
# 315678 To Beaverton TCR
# 3157"J
#
# ßE6Bª=õÂ4C* (øİõ”:7517B
# 315775 to 45-HarneyZ
# 3162"R
#
# ‘6BZõÂICB (òİõ”:7642B
# 31624  To SW 5th & JeffersonP
# 3166"H
#
# øü5Be\õÂ+C, (éİõ”:8455B
# 31668  To NE Dekum[
# 3168"S
#
# ¤¾5Bf#õÂ°C (õİõ”:13248B
# 316833 To Clackamas CollegeV
# 3203"N
#
# ™h6BW†õÂHB (àİõ”:10095B
# 320344 To PCC Sylvania\
# 3205"T
#
# x$6BĞeõÂ2C- (éİõ”:14032B
# 320524 To SW 18th & MorrisonT
# 3206"L
#
# �6BØöÂ¼B (õİõ”:267B
# 320657 To Beaverton TCT
# 3224"L
#
# ÿ6B;öÂC (ûİõ”:146B
# 322457 To Beaverton TCS
# 3231"K
#
# Â5B�õÂiC) (ïİõ”:10639B
# 323112 To Tigard TCS
# 3232"K
#
# o;6B,!õÂqC (ãİõ”:10855B
# 323212 To Tigard TCU
# 3233"M
#
# Á5B�õÂ€ªC) (æİõ”:2234B
# 323376 To Beaverton TCV
# 3234"N
#
# Ø6B[ãõÂÄB) (õİõ”:10157B
# 323457 To Beaverton TCQ
# 3237"I
#
# C (æİõ”:8211B
# 323794 To Sherwood^
# 3238"V
#
# ã6B"XõÂ°B (æİõ”:11817B#
# 32388  To NE M L King & LombardU
# 3242"M
#
# 7#6B‹¹õÂsC (òİõ”:9012B
# 324248 To Hillsboro TCR
# 3244"J
#
# ŠM6B–RõÂ¨C% (àİõ”:5918B
# 32446  Jantzen BeachQ
# 3245"I
#
# zÂ5BBtõÂ³C (àİõ”:8951B
# 324544 To St JohnsS
# 3255"K
#
# S6B>^õÂ‘C0 (àİõ”:3051B
# 32556  To SW 18th AveS
# 3256"K
#
# ú 6BïäõÂ´B (òİõ”:10193B
# 325648 To Sunset TCQ
# 3260"I
#
# �Ï5BË�õÂ (àİõ”:9650B
# 326056 To PortlandP
# 3261"H
#
# ‡ö5B:šõÂUC (ãİõ”:9654B
# 20 Gresham TC\
# 3262"T
#
# ¨ğ5B¥YõÂªC+ (õİõ”:3616B!
# 326235 University of PortlandX
# 3268"P
#
# ”-6BjÉôÂºB (İİõ”:9473B
# 326877 To Montgomery ParkS
# 3303"K
#
# 6BêŞôÂ4C/ (æİõ”:1579B
# 330321 To Gresham TCQ
# 3304"I
#
# Zô5B“]õÂ:C3 (ìİõ”:155B
# 330412 To Tigard TCR
# 3313"J
#
# V6BÀ?õÂ´B (æİõ”:2625B
# 331314 To 94-FosterP
# 3316"H
#
# Ó6B9*õÂ²B@ (ìİõ”:6165B
# 15 Gateway TCS
# 3317"K
#
# o6BwõÂ€‡C (ãİõ”:8917B
# 331715 Montgomery PkN
# 3318"F
#
# ÅG6B‰YõÂ4C, (õİõ”:92B
# 33184  To PortlandQ
# 3320"I
#
# 	O6B\õÂ…C  (ïİõ”:3507B
# 33204  To St. JohnsQ
# 3323"I
#
# õ$6Bâ^õÂC% (ìİõ”:9892B
# 332316 To PortlandR
# 3327"J
#
# 6Bğ[õÂ‘C (õİõ”:12791B
# 33274  To St. Johns^
# 3328"V
#
# \É5B^?õÂ´B; (ûİõ”:2582B#
# 332833 To Clackamas Town CenterR
# 3330"J
#
# —ê5B#õÂÆB# (ìİõ”:6398B
# 333014 To 94-FosterT
# 3504"L
#
# ­+6B�5õÂ€?: (ïİõ”:7737B
# 350471 To Parkrose TCQ
# 3511"I
#
# Ù=6B¥LõÂ4C (ïİõ”:6813B
# 35118  OHSU-VA HospR
# 3517"J
#
# c6B„õÂˆC= (øİõ”:13479B
# 35174  To St. JohnsP
# 3520"H
#
# ~q6BÚ\õÂUC (éİõ”:1026B
# 35206  To PortlandQ
# 3521"I
#
# õÂ²B (àİõ”:2685B
# 352117 To Saratoga[
# 3533"S
#
# D86BA(õÂ4C/ (ãİõ”:8025B
# 353372 To Clackamas Town CtrX
# 3540"P
#
# †"6Bß5õÂ‡C; (õİõ”:2431B
# 354077 To Montgomery ParkQ
# 3550"I
#
# ­ê5Bñ!õÂ€‘C (æİõ”:1831B
# 355014 To PortlandP
# 3553"H
#
# „ş5B£HõÂ’CD (ãİõ”:4626B
# 35539  To PortlandO
# 3560"G
#
# é6BßdõÂ¼B (ûİõ”:718B
# 15 Gateway TCP
# 3562"H
#
# n]6B‡rõÂ´B (éİõ”:1722B
# 35624  To PortlandP
# 3575"H
#
# Ì&6BòiõÂ2C (øİõ”:8484B
# 15 Gateway TCQ
# 3577"I
#
# ¨"6Bo(õÂªC. (àİõ”:8042B
# 357772 Swan IslandQ
# 3601"I
#
# 7@6B*DõÂ€†CH (ûİõ”:3189B
# 360172 Swan IslandR
# 3604"J
#
# œ6BgûôÂ‡C( (òİõ”:5459B
# 360420 Beaverton TCV
# 3609"N
#
# ˜6BWõÂ4C (øİõ”:6623B
# 360973 To Foster & 94thS
# 3613"K
#
# Ô6B¬ÚôÂĞB (ìİõ”:10857B
# 361320 Beaverton TCX
# 3617"P
#
# "¾5B#õÂ.C (ãİõ”:13248B
# 361731 To Oregon City TC_
# 3618"W
#
# ¾5B#õÂ¢B (éİõ”:13247B#
# 361879 To Clackamas Town CenterO
# 3621"G
#
# Lı5B>õÂ¦B (øİõ”:4651B
# 9  Gresham TCO
# 3634"G
#
# é6BDQõÂ4C
#  (éİõ”:7855B
# 2  Gresham TCU
# 3641"M
#
# �ö5B6šõÂUC (æİõ”:8169B
# 364157 To Forest GroveP
# 3645"H
#
# ùY6Bì€õÂMC (øİõ”:4818B
# 36454  To Portland]
# 3646"U
#
# á6BvXõÂ°B) (àİõ”:1612B"
# 364644 Mocks Crest to St JohnsQ
# 3701"I
#
# õ5B41õÂ€–C
#  (ìİõ”:1778B
# 370114 To PortlandT
# 3710"L
#
# 5#6BFõÂ  (éİõ”:6628B
# 371073 To Parkrose TCQ
# 3713"I
#
# ı6BÛôÂ²B (òİõ”:10858B
# 37139  To Portland[
# 3720"S
#
# sÔ5B�(õÂ4C^ (ãİõ”:7988B
# 372072 To Clackamas Town CtrQ
# 3721"I
#
# 6B3ÛôÂÚB (õİõ”:12757B
# 37212  To PortlandP
# 3730"H
#
# Á6BZ'õÂ¾B% (àİõ”:14143B
# 2  Gresham TCP
# 3733"H
#
# r6Bÿ7õÂ€†C4 (àİõ”:1470B
# 37332  To PortlandQ
# 3739"I
#
# =@6BdõÂ€†C_ (ãİõ”:3167B
# 373972 Swan IslandP
# 3744"H
#
# æö5B	šõÂeC (ûİõ”:9654B
# 20 Gresham TCU
# 3746"M
#
# ß6B“½õÂâB (æİõ”:9621B
# 374688 To Beaverton TCP
# 3750"H
#
# ¿ñ5BĞ€õÂ²B (ïİõ”:348B
# 375054 To Portland^
# 3752"V
#
# Üp5BŒ5õÂC (ìİõ”:8760B#
# 375231 To Clackamas Town Center\
# 3754"T
#
# }<6BËIõÂ´B (ìİõ”:11471B
# 375472 To Clackamas Town CtrR
# 3755"J
#
# ğ6BVÔôÂ²B (æİõ”:1339B
# 375520 Beaverton TCZ
# 3803"R
#
# [11562135*62
# 6Bl�õÂ€”C (ìİõ”:9625B
# 380362 To Washington SquareR
# 3804"J
#
# ’ø5B¤£õÂÜB" (ïİõ”:3892B
# 380462 To Sunset TCZ
# 3805"R
#
# Ä5B¬¡õÂøA. (ìİõ”:8614B
# 380562 To Washington SquareU
# 3903"M
#
# ë5B»"õÂ€‘C (òİõ”:14002B
# 390373 To Parkrose TCO
# 3916"G
#
# l6BÁYõÂ:C (øİõ”:9301B
# 2  Gresham TCQ
# 3918"I
#
# m6B…5õÂ´B? (ìİõ”:12955B
# 20 Gresham TCZ
# 3920"R
#
# Û6BVõÂ�CI (ãİõ”:11956B
# 39202  To NW 6th & FlandersT
# 3926"L
#
# Û;6BÇ õÂC (ïİõ”:10854B
# 392621 To Gresham TCP
# 3927"H
#
# œ6B�ÿôÂ²B] (ûİõ”:5452B
# 20 Gresham TC_
# 3928"W
#
# è¿5B¿%õÂ€‡C (øİõ”:12922B"
# 3928155 To Sunnyside-172nd AveW
# 3929"O
#
# _®5BĞ&õÂ)C (òİõ”:8075B
# 392979 To Oregon City TC[
# 3930"S
#
# V16Bú*õÂ‡C (æİõ”:1905B
# 393024 To SW 18th & MorrisonO
# 3931"G
#
# õÂ¤B/ (ãİõ”:4585B
# 9  Gresham TCQ
# 3933"I
#
# ™6B�UõÂ€‡C^ (æİõ”:689B
# 393320 Beaverton TCQ
# 3935"I
#
# @6B_~õÂ‰Cp (õİõ”:252B
# 393520 Beaverton TCR
# 3941"J
#
# Ÿ¾5Bf#õÂ°C (ìİõ”:13248B
# 394172 Swan IslandP
# 3942"H
#
# +6B8929*2
# õÂ€†C (ìİõ”:1390B
# 39422  To PortlandO
# 3944"G
#
# �6B*\õÂHC (æİõ”:7594B
# 9  Gresham TCT
# 3947"L
#
# Z$6B‹bõÂ€‹C (ïİõ”:14040B
# 394724 To Gateway TC_
# 3951"W
#
# "¾5B#õÂ.C (ûİõ”:13248B"
# 3951155 To Sunnyside-172nd AveQ
# 3962"I
#
# »5BÉˆõÂ4B (ãİõ”:3669B
# 396212 Parkrose TCV
# 4001"N
#
# Y6B²[õÂHC (õİõ”:13167B
# 400154 To Beaverton TCQ
# 4006"I
#
# 46B—EõÂ4C (ìİõ”:7307B
# 400617 To SE 134thS
# 4008"K
#
# Î6BCRõÂ€? (ïİõ”:10953B
# 40086  Jantzen BeachR
# 4010"J
#
# M"6BşõÂ´B9 (ìİõ”:2358B
# 401077 To TroutdaleT
# 4015"L
#
# Dç5B1õÂ²BP (ïİõ”:1539B
# 401519 Mt Scott-112thW
# 4023"O
#
# ºU6BødõÂ4C (øİõ”:4435B
# 402335 To Oregon City TCU
# 4026"M
#
# ³¿5Ba$õÂˆC (øİõ”:12922B
# 402671 To Parkrose TCQ
# 4028"I
#
# úN6B!_õÂ‡CV (ãİõ”:3485B
# 402875 to St JohnsQ
# 4032"I
#
# 6B%QõÂ‡C (Êİõ”:3633B
# 403214 To PortlandR
# 4036"J
#
#  6Bø>õÂ4C= (àİõ”:7483B
# 403675 to 45-Harney^
# 4040"V
#
# ´I5B‡&õÂB (æİõ”:1068B#
# 404033 To Clackamas Town CenterT
# 4041"L
#
# ø6BX õÂ%C (òİõ”:8194B
# 404119 Mt Scott-112thQ
# 4042"I
#
# 6BÔ>õÂ€³C (ãİõ”:7468B
# 404275 to St JohnsP
# 4043"H
#
# 6BÊÌôÂ3C| (õİõ”:3093B
# 20 Gresham TCP
# 4044"H
#
# �6B½ õÂ€­C (òİõ”:8194B
# 15 To NW Yeon[
# 4049"S
#
# 6BM(õÂ4CK (òİõ”:8024B
# 404972 To Clackamas Town CtrU
# 4051"M
#
# ×6BYõÂ‘C4 (ãİõ”:6158B
# 405115 To NW Yeon-44thZ
# 4058"R
#
# Kk5By6õÂúB: (ïİõ”:7609B
# 405833 To Clackamas College'
# úù5BîKõÂ°C(òİõ”B
# 4062U
# 4069"M
#
# ·6B3UõÂbC2 (ûİõ”:2592B
# 406944 To PCC Sylvania
