# %%
from pathlib import Path

import gtfstk as gt
import pandas as pd
import numpy as np

# %%
DATA_DIR = Path("data/")
# %ls {DATA_DIR}
# Out:
# gtfs.zip

# %%
# Read GTFS feed
feed = gt.read_gtfs(DATA_DIR/"gtfs.zip", dist_units="km")
feed.describe()
# Out:
#                            indicator                                value
# 0                           agencies  [LADOT, LADOT, LADOT, LADOT, LADOT]
# 1                           timezone                  America/Los_Angeles
# 2                         start_date                             20200418
# 3                           end_date                             20991231
# 4                         num_routes                                   62
# 5                          num_trips                                 6851
# 6                          num_stops                                 2678
# 7                         num_shapes                                  106
# 8                        sample_date                             20200423
# 9   num_routes_active_on_sample_date                                    0
# 10   num_trips_active_on_sample_date                                    0
# 11   num_stops_active_on_sample_date                                    0

# %%
feed.validate()
# Out:
#       type                                            message       table  \
# 0    error  Invalid agency_lang; maybe has extra space cha...      agency
# 4    error  Invalid feed_lang; maybe has extra space chara...   feed_info
# 1  warning                   Unrecognized column default_lang   feed_info
# 2  warning             Unrecognized column feed_contact_email   feed_info
# 3  warning               Unrecognized column feed_contact_url   feed_info
# 5  warning  Repeated pair (route_short_name, route_long_name)      routes
# 9  warning            Repeated pair (trip_id, departure_time)  stop_times
# 6  warning                       Unrecognized column level_id       stops
# 7  warning                  Unrecognized column platform_code       stops
# 8  warning                             Stop has no stop times       stops
#
#                                                 rows
# 0                                    [0, 1, 2, 3, 4]
# 4                                                [0]
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 5                                               [11]
# 9  [104, 114, 149, 159, 212, 214, 217, 236, 244, ...
# 6                                                 []
# 7                                                 []
# 8  [9, 17, 1384, 1856, 2009, 2249, 2267, 2268, 22...

# %%
# Trips table
feed.trips.T
# Out:
#                                   0                         1     \
# trip_id                 183-_3uV2MjGIO           183-_694En4HMYp
# route_id                          4445                      4446
# service_id                          14                        14
# trip_headsign          EXPO PARK - USC  Union Station/South Park
# trip_short_name                    NaN                       NaN
# direction_id                         0                         1
# block_id                        286991                    286993
# shape_id                         13220                     18480
# wheelchair_accessible              NaN                       NaN
#
#                                   2                         3     \
# trip_id                 183-_YUYwDUy6X           183--784XcojfNQ
# route_id                          4445                      4446
# service_id                          14                        14
# trip_headsign          EXPO PARK - USC  Union Station/South Park
# trip_short_name                    NaN                       NaN
# direction_id                         0                         0
# block_id                        286990                    286995
# shape_id                         13220                     17538
# wheelchair_accessible              NaN                       NaN
#
#                                            4                         5     \
# trip_id                         183--HZ6PxH8z9R           183--N47c2f9CGf
# route_id                                   4446                      4446
# service_id                                   14                        14
# trip_headsign          Union Station/South Park  Union Station/South Park
# trip_short_name                             NaN                       NaN
# direction_id                                  1                         0
# block_id                                 286979                    286997
# shape_id                                  18480                     17538
# wheelchair_accessible                       NaN                       NaN
#
#                                            6                       7     \
# trip_id                           183-00t9z1nfl           183-031a0ikvr
# route_id                                   4446                    4447
# service_id                                   12                      12
# trip_headsign          Union Station/South Park  Little Tokyo/City West
# trip_short_name                             NaN                     NaN
# direction_id                                  1                       0
# block_id                                 286914                  286895
# shape_id                                  18480                   18751
# wheelchair_accessible                       NaN                     NaN
#
#                                       8                    9     ...  \
# trip_id                      183-045yfk8ua        183-04hytkcoa  ...
# route_id                              4444                 4444  ...
# service_id                              12                   12  ...
# trip_headsign          To Fashion District  To Fashion District  ...
# trip_short_name                        NaN                  NaN  ...
# direction_id                             0                    0  ...
# block_id                            286926               286934  ...
# shape_id                             16607                16607  ...
# wheelchair_accessible                  NaN                  NaN  ...
#
#                                        6841                           6842  \
# trip_id                        47-zq19fh7pv                 47-zQBxObi71XT
# route_id                                 30                            801
# service_id                               10                             10
# trip_headsign          422 to Thousand Oaks  Sepulveda Park via Kester Ave
# trip_short_name                         NaN                            NaN
# direction_id                              0                              0
# block_id                             276891                         276838
# shape_id                              13226                           7854
# wheelchair_accessible                   NaN                            NaN
#
#                                                 6843          6844  \
# trip_id                               47-zQfMBOCKbgf  47-zr37opyrh
# route_id                                         801           867
# service_id                                        10            10
# trip_headsign          Sepulveda Park via Kester Ave  To Expo Park
# trip_short_name                                  NaN           NaN
# direction_id                                       0             1
# block_id                                      276837        276882
# shape_id                                        7854          4186
# wheelchair_accessible                            NaN           NaN
#
#                                                    6845  \
# trip_id                                   47-zRD6nUAqeG
# route_id                                            804
# service_id                                           11
# trip_headsign          Sepulveda Park via Van Nuys Blvd
# trip_short_name                                     NaN
# direction_id                                          0
# block_id                                         276976
# shape_id                                           7855
# wheelchair_accessible                               NaN
#
#                                                    6846  \
# trip_id                                  47-zrxsnpruzxW
# route_id                                            804
# service_id                                           10
# trip_headsign          Sepulveda Park via Van Nuys Blvd
# trip_short_name                                     NaN
# direction_id                                          0
# block_id                                         276843
# shape_id                                           7855
# wheelchair_accessible                               NaN
#
#                                                 6847  \
# trip_id                               47-zt_Hf3luUEO
# route_id                                         801
# service_id                                         9
# trip_headsign          Sepulveda Park via Kester Ave
# trip_short_name                                  NaN
# direction_id                                       0
# block_id                                      276826
# shape_id                                        7854
# wheelchair_accessible                            NaN
#
#                                             6848                6849  \
# trip_id                           47-zukU0RTiA0c      47-zWoSzHKcr5c
# route_id                                     800                5285
# service_id                                    11                  10
# trip_headsign          Civic Center via Whitsett  To Mission College
# trip_short_name                              NaN                 NaN
# direction_id                                   0                   0
# block_id                                  276972              276845
# shape_id                                   15089               18148
# wheelchair_accessible                        NaN                 NaN
#
#                                              6850
# trip_id                            47-ZZEi1FcnqL4
# route_id                                      799
# service_id                                      9
# trip_headsign          Civic Center via Hazeltine
# trip_short_name                               NaN
# direction_id                                    0
# block_id                                   276821
# shape_id                                    15088
# wheelchair_accessible                         NaN
#
# [9 rows x 6851 columns]

# %%
# Onl show route, trip, and shape columns: slice columns, AKA filter
feed.trips.filter(["route_id", "trip_id", "shape_id"]).T
# Out:
#                     0                1               2                3     \
# route_id            4445             4446            4445             4446
# trip_id   183-_3uV2MjGIO  183-_694En4HMYp  183-_YUYwDUy6X  183--784XcojfNQ
# shape_id           13220            18480           13220            17538
#
#                      4                5              6              7     \
# route_id             4446             4446           4446           4447
# trip_id   183--HZ6PxH8z9R  183--N47c2f9CGf  183-00t9z1nfl  183-031a0ikvr
# shape_id            18480            17538          18480          18751
#
#                    8              9     ...          6841            6842  \
# route_id           4444           4444  ...            30             801
# trip_id   183-045yfk8ua  183-04hytkcoa  ...  47-zq19fh7pv  47-zQBxObi71XT
# shape_id          16607          16607  ...         13226            7854
#
#                     6843          6844           6845            6846  \
# route_id             801           867            804             804
# trip_id   47-zQfMBOCKbgf  47-zr37opyrh  47-zRD6nUAqeG  47-zrxsnpruzxW
# shape_id            7854          4186           7855            7855
#
#                     6847            6848            6849            6850
# route_id             801             800            5285             799
# trip_id   47-zt_Hf3luUEO  47-zukU0RTiA0c  47-zWoSzHKcr5c  47-ZZEi1FcnqL4
# shape_id            7854           15089           18148           15088
#
# [3 rows x 6851 columns]

# %%
# 10 unique route_ids from trips.txt
# Remove slice to get all route_ids
np.vstack(feed.trips.route_id.unique())[0:10]
# Out:
# array([['4445'],
#        ['4446'],
#        ['4447'],
#        ['4444'],
#        ['4443'],
#        ['563'],
#        ['605'],
#        ['603'],
#        ['4868'],
#        ['572']], dtype='<U4')

# %%
# Find all trips of a specfic route: slice rows
feed.trips.loc[lambda x: x.route_id == "572"].T
# Out:
#                                                             1649  \
# trip_id                                         30-0__eb8iPEGugV
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287352
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1659  \
# trip_id                                         30-0_-1gLpMd2YmR
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287351
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1684  \
# trip_id                                         30-0_0cy0Vv1P4Tv
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287351
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1690  \
# trip_id                                         30-0_0s93ipl-1mp
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287352
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1722  \
# trip_id                                         30-0_1VodfOH7LmX
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287352
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1777  \
# trip_id                                         30-0_4AExetngIyJ
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287352
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1784  \
# trip_id                                         30-0_4lHazv_R7SB
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287352
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1841  \
# trip_id                                         30-0_6QjFQlMeMHT
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287351
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1891  \
# trip_id                                         30-0_9E--mlxDNbx
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287351
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1930  ...  \
# trip_id                                         30-0_ag28eca58XW  ...
# route_id                                                     572  ...
# service_id                                                     0  ...
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH  ...
# trip_short_name                                              NaN  ...
# direction_id                                                   0  ...
# block_id                                                  287351  ...
# shape_id                                                    8397  ...
# wheelchair_accessible                                        NaN  ...
#
#                                                             4307  \
# trip_id                                         30-2_OutoX_80hCU
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287463
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4337  \
# trip_id                                         30-2_px0_PM3Gckm
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287463
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4355  \
# trip_id                                         30-2_QU-hge-RF_o
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287463
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4356  \
# trip_id                                         30-2_QuNHb2k34Kq
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287463
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4385  \
# trip_id                                         30-2_rQ8mgbpag3k
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287462
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4442  \
# trip_id                                         30-2_tWMaszH7kAp
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287462
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4479  \
# trip_id                                         30-2_VDatc-H6AOY
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287462
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4542  \
# trip_id                                         30-2_XDFMJD8u4ty
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287463
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4598  \
# trip_id                                         30-2_zBk7y4apbkH
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287462
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4604
# trip_id                                         30-2_znMFe9a6ZSB
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287463
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
# [9 rows x 96 columns]

# %%
# Group all trips by route: group
feed.trips.groupby("route_id").get_group("572").T
# Out:
#                                                             1649  \
# trip_id                                         30-0__eb8iPEGugV
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287352
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1659  \
# trip_id                                         30-0_-1gLpMd2YmR
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287351
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1684  \
# trip_id                                         30-0_0cy0Vv1P4Tv
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287351
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1690  \
# trip_id                                         30-0_0s93ipl-1mp
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287352
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1722  \
# trip_id                                         30-0_1VodfOH7LmX
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287352
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1777  \
# trip_id                                         30-0_4AExetngIyJ
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287352
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1784  \
# trip_id                                         30-0_4lHazv_R7SB
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287352
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1841  \
# trip_id                                         30-0_6QjFQlMeMHT
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287351
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1891  \
# trip_id                                         30-0_9E--mlxDNbx
# route_id                                                     572
# service_id                                                     0
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287351
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             1930  ...  \
# trip_id                                         30-0_ag28eca58XW  ...
# route_id                                                     572  ...
# service_id                                                     0  ...
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH  ...
# trip_short_name                                              NaN  ...
# direction_id                                                   0  ...
# block_id                                                  287351  ...
# shape_id                                                    8397  ...
# wheelchair_accessible                                        NaN  ...
#
#                                                             4307  \
# trip_id                                         30-2_OutoX_80hCU
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287463
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4337  \
# trip_id                                         30-2_px0_PM3Gckm
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287463
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4355  \
# trip_id                                         30-2_QU-hge-RF_o
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287463
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4356  \
# trip_id                                         30-2_QuNHb2k34Kq
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287463
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4385  \
# trip_id                                         30-2_rQ8mgbpag3k
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287462
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4442  \
# trip_id                                         30-2_tWMaszH7kAp
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287462
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4479  \
# trip_id                                         30-2_VDatc-H6AOY
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287462
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4542  \
# trip_id                                         30-2_XDFMJD8u4ty
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287463
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4598  \
# trip_id                                         30-2_zBk7y4apbkH
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287462
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
#                                                             4604
# trip_id                                         30-2_znMFe9a6ZSB
# route_id                                                     572
# service_id                                                     2
# trip_headsign          WILSHIRE CENTER/KOREATOWN VERMONT VIA 9TH
# trip_short_name                                              NaN
# direction_id                                                   0
# block_id                                                  287463
# shape_id                                                    8397
# wheelchair_accessible                                        NaN
#
# [9 rows x 96 columns]

# %%
# Computer number of trips per route: split, apply, combine
def my_agg(group):
    d = {}
    d["num_trips"] = group.shape[0]
    return pd.Series(d)

# Use method chaining
(
    feed.trips
    #Split
    .groupby("route_id")
    .apply(my_agg)
    .reset_index()
    # Join in route short name from feed.routes
    .merge(feed.routes.filter(["route_id", "route_short_name", "route_long_name", "route_type"]))
    .sort_values("num_trips", ascending=False)
    .T
)
# Out:
#                       15                         22      17  \
# route_id            4444                       4869    4446
# num_trips            576                        448     442
# route_short_name       E       Pico Union/Echo Park       D
# route_long_name   DASH E  DASH Pico Union/Echo Park  DASH D
# route_type             3                          3       3
#
#                                           19                           21  \
# route_id                                4577                         4868
# num_trips                                311                          280
# route_short_name       Observatory/Los Feliz       El Sereno/City Terrace
# route_long_name   DASH Observatory/Los Feliz  DASH El Sereno/City Terrace
# route_type                                 3                            3
#
#                       18      14      16                        44     59  \
# route_id            4447    4443    4445                       712    870
# num_trips            225     209     193                       193    192
# route_short_name       A       B       F       Chesterfield Square    142
# route_long_name   DASH A  DASH B  DASH F  DASH Chesterfield Square  CE142
# route_type             3       3       3                         3      3
#
#                   ...     6       55       0       58      13      60     5   \
# route_id          ...     27     858     1458     869    4291     871     26
# num_trips         ...     14      12       11      10       8       8      6
# route_short_name  ...    438    437A     438B     574     439     534    431
# route_long_name   ...  CE438  CE437A  CE438B   CE574   CE439   CE534   CE431
# route_type        ...      3       3        3       3       3       3      3
#
#                      11      12      1
# route_id           4278    4290    1524
# num_trips             4       4       2
# route_short_name    438    437B    431B
# route_long_name   CE438  CE437B  CE431B
# route_type            3       3       3
#
# [5 rows x 62 columns]
