# %%
from pathlib import Path

import gtfstk as gt
import pandas as pd
import nunmpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_17068/3195553885.py in <module>
#       1 from pathlib import Path
#       2
# ----> 3 import gtfstk as gt
#       4 import pandas as pd
#       5 import nunmpy as np
#
# ModuleNotFoundError: No module named 'gtfstk'

# %%
# !pip freeze
# Out:
# absl-py==0.15.0
# aiobotocore==1.4.2
# aiohttp==3.7.4.post0
# aioitertools==0.8.0
# algopy==0.5.7
# ansi2html==1.6.0
# anyio @ file:///Users/runner/miniforge3/conda-bld/anyio_1626998849651/work/dist
# appdirs==1.4.4
# appnope @ file:///Users/runner/miniforge3/conda-bld/appnope_1610094676799/work
# arch==5.0.1
# argon2-cffi @ file:///Users/runner/miniforge3/conda-bld/argon2-cffi_1625821489228/work
# astunparse==1.6.3
# async-generator==1.10
# async-timeout==3.0.1
# attrs @ file:///home/conda/feedstock_root/build_artifacts/attrs_1620387926260/work
# autokeras==1.0.16.post1
# Babel @ file:///home/conda/feedstock_root/build_artifacts/babel_1619719576210/work
# backcall @ file:///home/conda/feedstock_root/build_artifacts/backcall_1592338393461/work
# backports.functools-lru-cache @ file:///home/conda/feedstock_root/build_artifacts/backports.functools_lru_cache_1618230623929/work
# beautifulsoup4==4.10.0
# ...
